# %% [markdown]
# # Uso de Dataframe en Pandas
# ##### https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html

# %%
import pandas as pd
import sys
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from pandas.tools.plotting import radviz

# %matplotlib inline

# %%
mi_df = pd.read_csv('data/data-educacion-ecuador.csv')
print mi_df.keys()
# Out:
# Index([u'Provincia', u'Canton', u'Parroquia', u'Femenino', u'Masculino',
#        u'Textbox17', u'Textbox6', u'Textbox7', u'Textbox18'],
#       dtype='object')

# %%
mi_df.head()
# Out:
#   Provincia                 Canton              Parroquia Femenino Masculino  \
# 0     AZUAY  CAMILO PONCE ENRIQUEZ  CAMILO PONCE ENRIQUEZ    2,294     2,096
# 1     AZUAY  CAMILO PONCE ENRIQUEZ   EL CARMEN DEL PIJILI      215       173
# 2     AZUAY              CHORDELEG              CHORDELEG    1,183     1,109
# 3     AZUAY              CHORDELEG               LA UNION      134       128
# 4     AZUAY              CHORDELEG  LUIS GALARZA ORELLANA      156       155
#
#   Textbox17   Textbox6   Textbox7  Textbox18
# 0     4,390  1,945,017  1,767,520  3,712,537
# 1       388  1,945,017  1,767,520  3,712,537
# 2     2,292  1,945,017  1,767,520  3,712,537
# 3       262  1,945,017  1,767,520  3,712,537
# 4       311  1,945,017  1,767,520  3,712,537

# %%
mi_df.dtypes
# Out:
# Provincia    object
# Canton       object
# Parroquia    object
# Femenino     object
# Masculino    object
# Textbox17    object
# Textbox6     object
# Textbox7     object
# Textbox18    object
# dtype: object

# %%
mi_df['Femenino'] = mi_df['Femenino'].str.replace(",", "").astype('float')

# %%
mi_df['Masculino'] = mi_df['Masculino'].str.replace(",", "").astype('float')

# %%
mi_df.dtypes
# Out:
# Provincia     object
# Canton        object
# Parroquia     object
# Femenino     float64
# Masculino    float64
# Textbox17     object
# Textbox6      object
# Textbox7      object
# Textbox18     object
# dtype: object

# %%
mi_df.head()
# Out:
#   Provincia                 Canton              Parroquia  Femenino  \
# 0     AZUAY  CAMILO PONCE ENRIQUEZ  CAMILO PONCE ENRIQUEZ    2294.0
# 1     AZUAY  CAMILO PONCE ENRIQUEZ   EL CARMEN DEL PIJILI     215.0
# 2     AZUAY              CHORDELEG              CHORDELEG    1183.0
# 3     AZUAY              CHORDELEG               LA UNION     134.0
# 4     AZUAY              CHORDELEG  LUIS GALARZA ORELLANA     156.0
#
#    Masculino Textbox17   Textbox6   Textbox7  Textbox18
# 0     2096.0     4,390  1,945,017  1,767,520  3,712,537
# 1      173.0       388  1,945,017  1,767,520  3,712,537
# 2     1109.0     2,292  1,945,017  1,767,520  3,712,537
# 3      128.0       262  1,945,017  1,767,520  3,712,537
# 4      155.0       311  1,945,017  1,767,520  3,712,537

# %%
mi_df.query('Femenino < 500')
# Out:
#              Provincia                 Canton  \
# 1                AZUAY  CAMILO PONCE ENRIQUEZ
# 3                AZUAY              CHORDELEG
# 4                AZUAY              CHORDELEG
# 5                AZUAY              CHORDELEG
# 6                AZUAY              CHORDELEG
# 10               AZUAY                 CUENCA
# 11               AZUAY                 CUENCA
# 20               AZUAY                 CUENCA
# 25               AZUAY                 CUENCA
# 26               AZUAY                 CUENCA
# 34               AZUAY                 CUENCA
# 41               AZUAY                 CUENCA
# 43               AZUAY                 EL PAN
# 44               AZUAY                 EL PAN
# 45               AZUAY                  GIRON
# 47               AZUAY                  GIRON
# 48               AZUAY             GUACHAPALA
# 49               AZUAY               GUALACEO
# 52               AZUAY               GUALACEO
# ...

# %%
mi_df[mi_df['Femenino'] < 1000]
# Out:
#              Provincia                 Canton  \
# 1                AZUAY  CAMILO PONCE ENRIQUEZ
# 3                AZUAY              CHORDELEG
# 4                AZUAY              CHORDELEG
# 5                AZUAY              CHORDELEG
# 6                AZUAY              CHORDELEG
# 10               AZUAY                 CUENCA
# 11               AZUAY                 CUENCA
# 12               AZUAY                 CUENCA
# 13               AZUAY                 CUENCA
# 20               AZUAY                 CUENCA
# 21               AZUAY                 CUENCA
# 24               AZUAY                 CUENCA
# 25               AZUAY                 CUENCA
# 26               AZUAY                 CUENCA
# 27               AZUAY                 CUENCA
# 30               AZUAY                 CUENCA
# 32               AZUAY                 CUENCA
# 34               AZUAY                 CUENCA
# 35               AZUAY                 CUENCA
# ...

# %%
mi_df[(mi_df['Femenino'] < 6000) & (mi_df['Femenino'] > 500)]
# Out:
#              Provincia                 Canton  \
# 0                AZUAY  CAMILO PONCE ENRIQUEZ
# 2                AZUAY              CHORDELEG
# 7                AZUAY                 CUENCA
# 8                AZUAY                 CUENCA
# 9                AZUAY                 CUENCA
# 12               AZUAY                 CUENCA
# 13               AZUAY                 CUENCA
# 14               AZUAY                 CUENCA
# 16               AZUAY                 CUENCA
# 17               AZUAY                 CUENCA
# 18               AZUAY                 CUENCA
# 19               AZUAY                 CUENCA
# 21               AZUAY                 CUENCA
# 22               AZUAY                 CUENCA
# 23               AZUAY                 CUENCA
# 24               AZUAY                 CUENCA
# 27               AZUAY                 CUENCA
# 28               AZUAY                 CUENCA
# 29               AZUAY                 CUENCA
# ...

# %%
mi_df[(mi_df['Canton'] =="LOJA") & (mi_df['Masculino'] > 1000)]
# Out:
#     Provincia Canton      Parroquia  Femenino  Masculino Textbox17   Textbox6  \
# 616      LOJA   LOJA    EL SAGRARIO   10147.0     8096.0    18,243  1,945,017
# 623      LOJA   LOJA  SAN SEBASTIAN    7875.0     7313.0    15,188  1,945,017
# 625      LOJA   LOJA          SUCRE    4092.0     4331.0     8,423  1,945,017
# 627      LOJA   LOJA          VALLE    5418.0     5223.0    10,641  1,945,017
#
#       Textbox7  Textbox18
# 616  1,767,520  3,712,537
# 623  1,767,520  3,712,537
# 625  1,767,520  3,712,537
# 627  1,767,520  3,712,537
